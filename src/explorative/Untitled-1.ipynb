# %%
import pandas as pd
import numpy as np

path = 'C:\\Users\\ranuc_id8e7tn\\OneDrive\\Documenti\\Projects\\MPM\\MPM\\data\\interim\\MPM_case_control_betas_T_nona.csv'
mpm = pd.read_csv(path, sep = ",", usecols = ['Unnamed: 0', 'cg00000029', 'cg00000108', 'cg00000109', 'cg00000165'])

# %%
path_pheno = 'C:\\Users\\ranuc_id8e7tn\\OneDrive\\Documenti\\Projects\\MPM\\MPM\\data\\processed\\MPM_case_control_phenotypes.csv'
pheno = pd.read_csv(path_pheno, sep=';')
pheno
# Out:
#                sampleID       iid        age  centre  outcome  gender  smoke  \
# 0    10011071006_R01C02    MESM74  61.889117  casale        1       1    2.0
# 1    10011071019_R02C01   MESTO60  70.343600  torino        1       2    3.0
# 2     3999423046_R03C02   CTRTO39  60.643395  torino        0       1    2.0
# 3     3999423046_R04C01   CTRTO33  77.382615  torino        0       1    2.0
# 4     3999423049_R03C02    CTR200  56.569473  casale        0       1    2.0
# ..                  ...       ...        ...     ...      ...     ...    ...
# 295   9007217062_R06C01  MESM42_2  77.390828  casale        1       2    3.0
# 296   8963311041_R05C01    CTR239  79.887748  casale        0       2    3.0
# 297   8963311058_R06C02    CTR211  48.117728  casale        0       2    1.0
# 298   9003865053_R01C02   MESTO21  68.276523  torino        1       2    3.0
# 299   9007217010_R06C02    CTR209  53.081451  casale        0       2    3.0
#
# ...

# %%
path.split('\\')
# Out:
# ['C:',
#  'Users',
#  'ranuc_id8e7tn',
#  'OneDrive',
#  'Documenti',
#  'Projects',
#  'MPM',
#  'MPM',
#  'data',
#  'interim',
#  'MPM_case_control_betas_T_nona.csv']

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'a': [0,1,1,1, np.nan], 'b':[2,2,2,2,np.nan]})
df.fillna(np.mean)
# Out:
#                                        a  \
# 0                                    0.0
# 1                                    1.0
# 2                                    1.0
# 3                                    1.0
# 4  <function mean at 0x0000024745A13940>
#
#                                        b
# 0                                    2.0
# 1                                    2.0
# 2                                    2.0
# 3                                    2.0
# 4  <function mean at 0x0000024745A13940>
